# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv2.imread('/home/usuario/second-brain/UFV/578-AnalisedeImagenseVisaoCompitacional/Docs/images/flower.jpeg')
cv2.namedWindow('Test', cv2.WINDOW_NORMAL)  # ← chave aqui!
cv2.resizeWindow('Test', 800, 600)          # tamanho inicial controlado
cv2.imshow('Test', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (2048, 946, 3)

# %%
img.size
# Out:
# 5812224

# %%
import cv2

img = cv2.imread('/home/usuario/second-brain/UFV/578-AnalisedeImagenseVisaoCompitacional/Docs/images/flower.jpeg')
if img is None:
    print("⚠️ Imagem não carregada! Verifique o caminho.")
    exit()

# Cria janela redimensionável explicitamente
cv2.namedWindow('Test', cv2.WINDOW_NORMAL)  # ← chave aqui!
cv2.resizeWindow('Test', 2048, 946)          # tamanho inicial controlado
cv2.imshow('Test', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QFontDatabase: Cannot find font directory /home/usuario/second-brain/UFV/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/usuario/second-brain/UFV/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/usuario/second-brain/UFV/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/usuario/second-brain/UFV/.venv/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ...

# %%
img2 = cv2.imread('/home/usuario/second-brain/UFV/578-AnalisedeImagenseVisaoCompitacional/Docs/images/flower.jpeg', cv2.IMREAD_GRAYSCALE)
img_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)  # OpenCV usa BGR, matplotlib usa RGB
plt.imshow(img_rgb)
plt.axis('off')
plt.show()
